# %% [markdown]
# # Types of RAG
# 1. Naive RAG
# 2. Advanced RAG (Optimized Retrieval)
# 3. Modular RAG
# 4. Graph RAG
# 5. Agentic RAG
# 6. Multimodal RAG
# 7. Corrective RAG

# %% [markdown]
# ### 1. Naive RAG
# > This is a simple RAG pipeline RAG + LLM. Here RAG is responsible to retrieve top K chunks and feed it to LLM

# %% [markdown]
# ### 2. Advanced RAG (Optimized Search)
# > Uses BM25 technique for ranking retrieved chunks from RAG which makes it more powerfull
